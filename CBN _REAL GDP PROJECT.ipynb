# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gdp= pd.read_csv('RealGDP01032021.csv')

# %%
gdp
# Out:
#     tyear  Period  Agriculture  CropProduction   Livestock   Forestry  \
# 0    1981  Annual   2364373.15      1854764.44   341411.50   77897.99
# 1    1982  Annual   2425960.89      1897078.85   361115.70   73910.25
# 2    1983  Annual   2409081.92      1842704.31   393131.01   75282.78
# 3    1984  Annual   2303505.42      1759115.15   399685.38   76694.14
# 4    1985  Annual   2731062.47      2180907.71   428102.85   78082.45
# ..    ...     ...          ...             ...         ...        ...
# 72   2018      Q4   4978775.48      4486166.16   341002.97   50038.06
# 73   2018  Annual  17544147.74     15786437.68  1208128.04  182747.93
# 74   2019      Q1   3597916.08      3144587.69   294971.65   42265.37
# 75   2019      Q2   3857705.59      3443607.45   283559.35   49559.78
# 76   2019      Q3   5408978.92      4994729.88   291218.38   44980.39
#
#       Fishing     Industry  CrudePetroleumAndNaturalGas  SolidMinerals  ...  \
# ...

# %%
gdp.rename(columns={'tyear':'Year'},inplace=True)

# %%
gdp
# Out:
#     Year  Period  Agriculture  CropProduction   Livestock   Forestry  \
# 0   1981  Annual   2364373.15      1854764.44   341411.50   77897.99
# 1   1982  Annual   2425960.89      1897078.85   361115.70   73910.25
# 2   1983  Annual   2409081.92      1842704.31   393131.01   75282.78
# 3   1984  Annual   2303505.42      1759115.15   399685.38   76694.14
# 4   1985  Annual   2731062.47      2180907.71   428102.85   78082.45
# ..   ...     ...          ...             ...         ...        ...
# 72  2018      Q4   4978775.48      4486166.16   341002.97   50038.06
# 73  2018  Annual  17544147.74     15786437.68  1208128.04  182747.93
# 74  2019      Q1   3597916.08      3144587.69   294971.65   42265.37
# 75  2019      Q2   3857705.59      3443607.45   283559.35   49559.78
# 76  2019      Q3   5408978.92      4994729.88   291218.38   44980.39
#
#       Fishing     Industry  CrudePetroleumAndNaturalGas  SolidMinerals  ...  \
# ...

# %%
gdp['Year'].unique()
# Out:
# array([1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
#: CALLING gdp['Period']== Q1,Q2,Q3,Q4

q = gdp[(gdp['Period']=='Q1')|(gdp['Period']=='Q2')|(gdp['Period']=='Q3')|(gdp['Period']=='Q4')]

# %%
q
# Out:
#     Year Period  Agriculture  CropProduction  Livestock  Forestry    Fishing  \
# 29  2010     Q1   2594759.86      2262178.08  237297.51  30420.97   64863.30
# 30  2010     Q2   2873377.57      2561460.05  216103.70  34382.27   61431.54
# 31  2010     Q3   4000028.64      3660097.23  247970.43  33750.81   58210.17
# 32  2010     Q4   3580726.73      3200161.01  278192.42  37166.85   65206.46
# 34  2011     Q1   2653864.07      2312358.57  240585.31  30163.56   70756.63
# 35  2011     Q2   2955290.83      2624438.47  224920.03  37660.06   68272.26
# 36  2011     Q3   4130570.31      3783265.06  249857.97  35774.21   61673.07
# 37  2011     Q4   3689653.56      3297129.90  284040.72  38861.55   69621.39
# 39  2012     Q1   2805803.39      2463380.44  235759.75  31434.46   75228.74
# 40  2012     Q2   3160094.68      2824154.48  224072.83  38095.64   73771.73
# 41  2012     Q3   4307966.75      3972238.15  234399.16  36461.52   64867.91
# ...

# %%
#: dropping the index of q above:

mi= q.index
for y in mi:
    gdp.drop(index=y,inplace=True)

# %%
gdp
# Out:
#     Year  Period  Agriculture  CropProduction   Livestock   Forestry  \
# 0   1981  Annual   2364373.15      1854764.44   341411.50   77897.99
# 1   1982  Annual   2425960.89      1897078.85   361115.70   73910.25
# 2   1983  Annual   2409081.92      1842704.31   393131.01   75282.78
# 3   1984  Annual   2303505.42      1759115.15   399685.38   76694.14
# 4   1985  Annual   2731062.47      2180907.71   428102.85   78082.45
# 5   1986  Annual   2986835.38      2427100.66   421627.97   86594.92
# 6   1987  Annual   2891672.33      2329995.84   433433.52   87594.28
# 7   1988  Annual   3174567.62      2581595.05   444269.94   88907.95
# 8   1989  Annual   3325947.09      2710674.81   453155.59   67307.31
# 9   1990  Annual   3464716.26      2828589.58   462218.99   72613.57
# 10  1991  Annual   3590837.44      2955875.91   454823.21   74791.90
# 11  1992  Annual   3674792.83      3044552.16   458916.79   76512.11
# 12  1993  Annual   3743665.81      3132843.73   461670.56   78042.40
# ...

# %%
# resetting the index:

gdp.reset_index(drop=True)
# Out:
#     Year  Period  Agriculture  CropProduction   Livestock   Forestry  \
# 0   1981  Annual   2364373.15      1854764.44   341411.50   77897.99
# 1   1982  Annual   2425960.89      1897078.85   361115.70   73910.25
# 2   1983  Annual   2409081.92      1842704.31   393131.01   75282.78
# 3   1984  Annual   2303505.42      1759115.15   399685.38   76694.14
# 4   1985  Annual   2731062.47      2180907.71   428102.85   78082.45
# 5   1986  Annual   2986835.38      2427100.66   421627.97   86594.92
# 6   1987  Annual   2891672.33      2329995.84   433433.52   87594.28
# 7   1988  Annual   3174567.62      2581595.05   444269.94   88907.95
# 8   1989  Annual   3325947.09      2710674.81   453155.59   67307.31
# 9   1990  Annual   3464716.26      2828589.58   462218.99   72613.57
# 10  1991  Annual   3590837.44      2955875.91   454823.21   74791.90
# 11  1992  Annual   3674792.83      3044552.16   458916.79   76512.11
# 12  1993  Annual   3743665.81      3132843.73   461670.56   78042.40
# ...

# %%
# total:

Total = []
yr = 1981 
while yr<2020:
    total= np.sum(oil[oil['Year']==yr]['Crude Oil Export(Mbd)'])
    Total_exp.append(np.round(total,1))
    yr= yr + 1

# %%
gdp.to_csv('REALGDP2018.csv')

# %%
gdp.to_excel('REALGDP.xlsx',sheet_name= '2018')

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Agriculture'],data= gdp)
plt.title('THE ANNUAL GDP OF AGRICULTURE FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF AGRICULTURE.png',dpi=150)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['CropProduction'],data= gdp)
plt.title('THE ANNUAL GDP OF CropProduction FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF CropProduction.png',dpi=150)
plt.show()

# %%
gdp.columns
# Out:
# Index(['Year', 'Period', 'Agriculture', 'CropProduction', 'Livestock',
#        'Forestry', 'Fishing', 'Industry', 'CrudePetroleumAndNaturalGas',
#        'SolidMinerals', 'Manufacturing', 'Construction', 'Trade', 'Services',
#        'Transport', 'InformationAndCommunication', 'Utilities',
#        'AccommodationAndFoodServices', 'FinanceAndInsurance', 'RealEstate',
#        'ProfessionalScientificAndTechnicalServices',
#        'AdministrativeAndSupportServicesBusinessServices',
#        'PublicAdministration', 'Education', 'HumanHealthAndSocialServices',
#        'ArtsEntertainmentAndRecreation', 'OtherServices', 'TOTAL_GDP',
#        'Clarified', 'ApprovalStatus', 'DateTimeSubmitted'],
#       dtype='object')

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Livestock'],data= gdp)
plt.title('THE ANNUAL GDP OF Livestock FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF Livestock.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Forestry'],data= gdp)
plt.title('THE ANNUAL GDP OF Forestry FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF Forestry.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Fishing'],data= gdp)
plt.title('THE ANNUAL GDP OF Fishing FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF Fishing.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Industry'],data= gdp)
plt.title('THE ANNUAL GDP OF Industry FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF Industry.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['CrudePetroleumAndNaturalGas'],data= gdp)
plt.title('THE ANNUAL GDP OF CrudePetroleumAndNaturalGas FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF CrudePetroleumAndNaturalGas.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['SolidMinerals'],data= gdp)
plt.title('THE ANNUAL GDP OF SolidMinerals FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF SolidMinerals.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Manufacturing'],data= gdp)
plt.title('THE ANNUAL GDP OF Manufacturing FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF Manufacturing.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Construction'],data= gdp)
plt.title('THE ANNUAL GDP OF Construction FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF Construction.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Trade'],data= gdp)
plt.title('THE ANNUAL GDP OF Trade FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF Trade.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Services'],data= gdp)
plt.title('THE ANNUAL GDP OF Services FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF Services.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Transport'],data= gdp)
plt.title('THE ANNUAL GDP OF Transport FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF Transport.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['TOTAL_GDP'],data= gdp)
plt.title('THE ANNUAL GDP OF TOTAL_GDP FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF TOTAL_GDP.png',dpi=350)
plt.show()

# %%
ax,fig=plt.subplots(figsize=(20,10),dpi=350)
sns.barplot(x= gdp['Year'],y= gdp['Education'],data= gdp)
plt.title('THE ANNUAL GDP OF EDUCATION FROM YEAR 1981 TO 2018')
plt.tight_layout()
plt.savefig('THE ANNUAL GDP OF Education.png',dpi=350)
plt.show()
